# %%
import os, inspect, sys
import json
import pandas as pd
import numpy as np

CURRENT_DIR = os.path.dirname(inspect.getabsfile(inspect.currentframe()))
ROOT_DIR = os.path.dirname(CURRENT_DIR)
sys.path.insert(0, ROOT_DIR)

# %%
ffname = os.path.join(ROOT_DIR, "reb", "data", "ext", "data_file.csv")

# %%
df = pd.read_csv(ffname)
df.head()
# Out:
#      Date  AWHNONAG  CES9091000001  CEU0500000003  LNS13023622  LNS13023654  \
# 0  2/1/87      34.9         3064.0            NaN         48.5         12.6
# 1  2/2/87      34.9         3064.0            NaN         48.5         12.6
# 2  2/3/87      34.9         3064.0            NaN         48.5         12.6
# 3  2/4/87      34.9         3064.0            NaN         48.5         12.6
# 4  2/5/87      34.9         3064.0            NaN         48.5         12.6
#
#    LNS13023706  LNS13026511  MARTSMPCSM44000USS  MNFCTRIRSA  MNFCTRMPCIMSA  \
# 0         13.1         35.9                 NaN         NaN            NaN
# 1         13.1         35.9                 NaN         NaN            NaN
# 2         13.1         35.9                 NaN         NaN            NaN
# 3         13.1         35.9                 NaN         NaN            NaN
# 4         13.1         35.9                 NaN         NaN            NaN
#
#    MNFCTRMPCSMSA  MPCT00XXS  MPCTNRXXS  MPCTXXXXS  MVPHGFD027MNFRBDAL  \
# 0            NaN        NaN        NaN        NaN              1768.3
# 1            NaN        NaN        NaN        NaN              1768.3
# 2            NaN        NaN        NaN        NaN              1768.3
# 3            NaN        NaN        NaN        NaN              1768.3
# 4            NaN        NaN        NaN        NaN              1768.3
#
#      PAYEMS  UNEMPLOY   USGOVT   USPRIV
# 0  100915.0    7865.0  17036.0  83879.0
# 1  100915.0    7865.0  17036.0  83879.0
# 2  100915.0    7865.0  17036.0  83879.0
# 3  100915.0    7865.0  17036.0  83879.0
# 4  100915.0    7865.0  17036.0  83879.0
