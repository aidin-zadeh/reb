# %%
import os, inspect, sys
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

from pandas.tools.plotting import autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf
import statsmodels.api as sm

CURRENT_DIR = os.path.dirname(inspect.getabsfile(inspect.currentframe()))
ROOT_DIR = os.path.dirname(CURRENT_DIR)
sys.path.insert(0, ROOT_DIR)

# %%
ffname = os.path.join(ROOT_DIR, "reb", "data", "ext", "Data_File_Monthly.csv")

# %%
df = pd.read_csv(ffname, parse_dates=["DATE"])
df.DATE = pd.to_datetime(df.DATE, format="%Y-%m")
df = df.loc[60:, :]


df.head()
# Out:
#          DATE  PAYEMS  CEU0500000003  USPRIV  AWHNONAG  CES9091000001  USGOVT  \
# 60 1992-01-01  108374            NaN   89686      34.1           3137   18688
# 61 1992-02-01  108317            NaN   89628      34.1           3121   18689
# 62 1992-03-01  108369            NaN   89654      34.1           3121   18715
# 63 1992-04-01  108526            NaN   89787      34.3           3117   18739
# 64 1992-05-01  108653            NaN   89900      34.3           3119   18753
#
#     UNEMPLOY  LNS13023622  LNS13023706   ...     MORTGAGE30US  MORTGAGE15US  \
# 60      9283         54.0         11.9   ...              8.4           8.0
# 61      9454         57.0          9.8   ...              8.8           8.4
# 62      9460         57.4          9.5   ...              8.9           8.6
# 63      9415         57.3         10.4   ...              8.9           8.5
# 64      9744         57.7         10.3   ...              8.7           8.3
#
#     DGS1  DGS2  DGS5  DGS10  Crude_Oil_Price   INDPRO    CMRMTSPL  W875RX1
# 60   NaN   NaN   NaN    7.0              NaN  63.3372  757479.217   6840.9
# 61   NaN   NaN   NaN    7.3              NaN  63.7864  759384.431   6879.1
# 62   NaN   NaN   NaN    7.5              NaN  64.3199  762440.896   6884.7
# 63   NaN   NaN   NaN    7.5              NaN  64.8069  767521.889   6903.6
# 64   NaN   NaN   NaN    7.4              NaN  65.0202  760844.122   6941.7
#
# [5 rows x 30 columns]

# %% [markdown]
# Make a clen copy of data. This allows us to modify freely while we have always the original data for any further reference.

# %%
df_original = df.copy()

# %% [markdown]
# Reindex data frame per the time stamps

# %%
df.set_index("DATE", inplace=True)
df.head()
# Out:
#             PAYEMS  CEU0500000003  USPRIV  AWHNONAG  CES9091000001  USGOVT  \
# DATE
# 1992-01-01  108374            NaN   89686      34.1           3137   18688
# 1992-02-01  108317            NaN   89628      34.1           3121   18689
# 1992-03-01  108369            NaN   89654      34.1           3121   18715
# 1992-04-01  108526            NaN   89787      34.3           3117   18739
# 1992-05-01  108653            NaN   89900      34.3           3119   18753
#
#             UNEMPLOY  LNS13023622  LNS13023706  LNS13023654   ...     \
# DATE                                                          ...
# 1992-01-01      9283         54.0         11.9         13.1   ...
# 1992-02-01      9454         57.0          9.8         13.6   ...
# 1992-03-01      9460         57.4          9.5         13.4   ...
# 1992-04-01      9415         57.3         10.4         13.6   ...
# 1992-05-01      9744         57.7         10.3         12.8   ...
#
#             MORTGAGE30US  MORTGAGE15US  DGS1  DGS2  DGS5  DGS10  \
# DATE
# 1992-01-01           8.4           8.0   NaN   NaN   NaN    7.0
# 1992-02-01           8.8           8.4   NaN   NaN   NaN    7.3
# 1992-03-01           8.9           8.6   NaN   NaN   NaN    7.5
# 1992-04-01           8.9           8.5   NaN   NaN   NaN    7.5
# 1992-05-01           8.7           8.3   NaN   NaN   NaN    7.4
#
#             Crude_Oil_Price   INDPRO    CMRMTSPL  W875RX1
# DATE
# 1992-01-01              NaN  63.3372  757479.217   6840.9
# 1992-02-01              NaN  63.7864  759384.431   6879.1
# 1992-03-01              NaN  64.3199  762440.896   6884.7
# 1992-04-01              NaN  64.8069  767521.889   6903.6
# 1992-05-01              NaN  65.0202  760844.122   6941.7
#
# [5 rows x 29 columns]

# %% [markdown]
# Check on the missing values

# %%
msno.matrix(df=df, figsize=(20, 10), color=(0.42, 0.1, 0.05))

# %% [markdown]
# Drop any columns with NaN values

# %%
# drop columns: axis=1; drop rows: axis=0
df.dropna(axis=1, inplace=True)

# %%
msno.matrix(df=df, figsize=(20, 10), color=(0.42, 0.1, 0.05))
df.columns
# Out:
# Index(['PAYEMS', 'USPRIV', 'AWHNONAG', 'CES9091000001', 'USGOVT', 'UNEMPLOY',
#        'LNS13023622', 'LNS13023706', 'LNS13023654', 'LNS13026511',
#        'MVPHGFD027MNFRBDAL', 'MORTGAGE30US', 'MORTGAGE15US', 'DGS10', 'INDPRO',
#        'W875RX1'],
#       dtype='object')

# %% [markdown]
# Check on distribution of variables

# %%
sns.set()
_ = df.hist(sharex=False,
            sharey=False,
            figsize=(12, 10))
plt.show()

# %% [markdown]
# Check on variable correlations

# %%
colormap = plt.cm.afmhot
plt.figure(figsize=(12,12))
plt.title('Pearson correlation', y=1.05, size=15)
sns.heatmap(df.corr(),
            linewidths=0.1,
            vmax=1.0,
            square=True, 
            cmap=colormap,
            linecolor='white',
            annot=True)
plt.show()

# %%
ncols = 2
fig, axs = plt.subplots(nrows=int(np.ceil(df.columns.size/ncols)),
                        ncols=ncols,
                        figsize=(12, 22),
                        sharex=True)
fig.tight_layout()
for idx, label in enumerate(df.columns):
    i = idx // ncols
    j = idx % ncols
    df[label].plot(title=label, ax=axs[i, j])

# %% [markdown]
# Check on autocorrelation plots to get an estimate of lag in the time series

# %%
ncols = 2
fig, axs = plt.subplots(nrows=int(np.ceil(df.columns.size/ncols)),
                        ncols=ncols,
                        figsize=(12, 22),
                        sharex=True)
fig.tight_layout()
for idx, label in enumerate(df.columns):
    i = idx // ncols
    j = idx % ncols
    plot_acf(df[label], title=label, ax=axs[i, j])

# %% [markdown]
# Detrend time series (make time series stationary)

# %%
#
#
#
#
#

# %% [markdown]
# Save prcessed data

# %%
ffname = os.path.join(ROOT_DIR, "reb", "data", "ext", "data_monthly_processed.csv")
df.to_csv(ffname)
