# %%
import os, inspect, sys
import json
import datetime as dt

CURRENT_DIR = os.path.dirname(inspect.getabsfile(inspect.currentframe()))
ROOT_DIR = os.path.dirname(CURRENT_DIR)
sys.path.insert(0, ROOT_DIR)

from reb.src import pynyt
from reb.conf import APIKEY_NYT_ARTICLE

# %%
def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + dt.timedelta(n), start_date + dt.timedelta(n+1)

# %%
nytArticle = pynyt.ArticleSearch(APIKEY_NYT_ARTICLE)
nytArchive = pynyt.ArchiveApi(APIKEY_NYT_ARTICLE)

# get 1000 news articles from the Foreign newsdesk from 1987    

for year in range(1990, 1996):
    for month in range(1, 13):
        start_date = dt.date(year, month, 1)
        end_date = dt.date(year + month//12,
                           (month+1)%12, 1)
        news_monthly = {}
        for d1, d2 in daterange(start_date, end_date):
            d1_str = d1.strftime("%Y%m%d")
            d2_str = d2.strftime("%Y%m%d")
            print(f"--> Reading NYT Business news from {d1_str}")

            news = nytArticle.query(
            #     q="obama",
                fq={"type_of_material": ["news"],
                    "section_name.contains": ["business", "Business Day", "Real Estate"]},
                begin_date=d1_str,
                end_date=d1_str,
                # facet_field=['source', 'day_of_week'],
                # facet_filter = True,
                verbose=True)
            
            news_daily = {"status": [],
                        "copyright": None,
                        "response": {"meta": [], "docs": []}}
            for x in news:
                news_daily["status"].append(x["status"])
                news_daily["copyright"] = x["copyright"]
                news_daily["response"]["meta"].append(x["response"]["meta"])
                news_daily["response"]["docs"].extend(x["response"]["docs"])
            news_monthly[d1_str] = news_daily
            
        fname = f"nyt-business-{year}-{month}.json"
        path = os.path.join(ROOT_DIR, "reb", "data", "raw")
        ffname = os.path.join(path, fname)
        with open(ffname, "w") as fp:
            json.dump(news_monthly, fp)
            print(f"--> Writing to '{fname}' at {path}")
# Out:
# --> Reading NYT Business news from 19900101
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900101&end_date=19900101&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900101&end_date=19900101&page=1
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900101&end_date=19900101&page=2
# Processing page 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900101&end_date=19900101&page=3
# --> Reading NYT Business news from 19900102
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900102&end_date=19900102&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900102&end_date=19900102&page=1
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900102&end_date=19900102&page=2
# Processing page 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900102&end_date=19900102&page=3
# --> Reading NYT Business news from 19900103
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900103&end_date=19900103&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900103&end_date=19900103&page=1
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900103&end_date=19900103&page=2
# Processing page 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900103&end_date=19900103&page=3
# Processing page 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900103&end_date=19900103&page=4
# Processing page 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900103&end_date=19900103&page=5
# --> Reading NYT Business news from 19900104
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900104&end_date=19900104&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900104&end_date=19900104&page=1
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900104&end_date=19900104&page=2
# Processing page 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900104&end_date=19900104&page=3
# --> Reading NYT Business news from 19900105
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900105&end_date=19900105&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900105&end_date=19900105&page=1
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900105&end_date=19900105&page=2
# Processing page 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900105&end_date=19900105&page=3
# Processing page 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900105&end_date=19900105&page=4
# --> Reading NYT Business news from 19900106
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900106&end_date=19900106&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900106&end_date=19900106&page=1
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900106&end_date=19900106&page=2
# Processing page 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900106&end_date=19900106&page=3
# --> Reading NYT Business news from 19900107
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900107&end_date=19900107&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900107&end_date=19900107&page=1
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900107&end_date=19900107&page=2
# Processing page 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900107&end_date=19900107&page=3
# --> Reading NYT Business news from 19900108
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900506&end_date=19900506&page=2
# Processing page 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900506&end_date=19900506&page=3
# --> Reading NYT Business news from 19900507
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900507&end_date=19900507&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900507&end_date=19900507&page=1
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900507&end_date=19900507&page=2
# Processing page 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900507&end_date=19900507&page=3
# --> Reading NYT Business news from 19900508
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900508&end_date=19900508&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900508&end_date=19900508&page=1
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900508&end_date=19900508&page=2
# Processing page 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900508&end_date=19900508&page=3
# Processing page 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900508&end_date=19900508&page=4
# Processing page 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900508&end_date=19900508&page=5
# --> Reading NYT Business news from 19900509
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900509&end_date=19900509&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900509&end_date=19900509&page=1
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900509&end_date=19900509&page=2
# Processing page 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900509&end_date=19900509&page=3
# Processing page 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900509&end_date=19900509&page=4
# Processing page 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900509&end_date=19900509&page=5
# --> Reading NYT Business news from 19900510
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900510&end_date=19900510&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900510&end_date=19900510&page=1
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900510&end_date=19900510&page=2
# Processing page 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900510&end_date=19900510&page=3
# Processing page 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900510&end_date=19900510&page=4
# Processing page 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900510&end_date=19900510&page=5
# --> Reading NYT Business news from 19900511
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900511&end_date=19900511&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900511&end_date=19900511&page=1
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900511&end_date=19900511&page=2
# Processing page 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900511&end_date=19900511&page=3
# Processing page 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900511&end_date=19900511&page=4
# Processing page 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900511&end_date=19900511&page=5
# --> Reading NYT Business news from 19900512
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900512&end_date=19900512&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900512&end_date=19900512&page=1
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900512&end_date=19900512&page=2
# --> Reading NYT Business news from 19900513
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900513&end_date=19900513&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900513&end_date=19900513&page=1
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900513&end_date=19900513&page=2
# Processing page 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900513&end_date=19900513&page=3
# --> Reading NYT Business news from 19900514
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900514&end_date=19900514&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900514&end_date=19900514&page=1
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900514&end_date=19900514&page=2
# Processing page 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900514&end_date=19900514&page=3
# --> Reading NYT Business news from 19900515
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900515&end_date=19900515&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900515&end_date=19900515&page=1
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900515&end_date=19900515&page=2
# Processing page 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900515&end_date=19900515&page=3
# Processing page 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900515&end_date=19900515&page=4
# Processing page 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900515&end_date=19900515&page=5
# --> Reading NYT Business news from 19900516
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900516&end_date=19900516&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900516&end_date=19900516&page=1
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900516&end_date=19900516&page=2
# Processing page 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900516&end_date=19900516&page=3
# Processing page 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900516&end_date=19900516&page=4
# --> Reading NYT Business news from 19900517
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900517&end_date=19900517&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900517&end_date=19900517&page=1
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900517&end_date=19900517&page=2
# Processing page 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900517&end_date=19900517&page=3
# Processing page 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900517&end_date=19900517&page=4
# Processing page 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900517&end_date=19900517&page=5
# Processing page 6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900517&end_date=19900517&page=6
# --> Reading NYT Business news from 19900518
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900518&end_date=19900518&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900518&end_date=19900518&page=1
# Processing page 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900518&end_date=19900518&page=2
# Processing page 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900518&end_date=19900518&page=3
# Processing page 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900518&end_date=19900518&page=4
# --> Reading NYT Business news from 19900519
# Processing page 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900519&end_date=19900519&page=0
# Processing page 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=type_of_material%3A%28news%29+AND+section_name.contains%3A%28business+Business+Day+Real+Estate%29&begin_date=19900519&end_date=19900519&page=1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-cbb2c7d0e915> in <module>()
#      23                 # facet_field=['source', 'day_of_week'],
#      24                 # facet_filter = True,
# ---> 25                 verbose=True)
#      26
#      27             news_daily = {"status": [],
#
# /media/aidin/data00/aidin/work/codes/projects/data-science/data-science-python/reb/reb/src/pynyt/__init__.py in query(self, halt_overflow, verbose, **kwargs)
#     155             parsed_json = json.loads(r.text)
#     156
# --> 157             if len(parsed_json['response']['docs']) == 0:  # no more results on this page -> all results parsed
#     158                 return results
#     159
#
# KeyError: 'response'
